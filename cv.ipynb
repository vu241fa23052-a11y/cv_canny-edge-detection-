# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
#function to display images
def show_comparision(original,sobel,prewitt,canny):
  plt.figure(figsize=(12,10))
#original image
  plt.subplot(2,2,1)
  plt.imshow(original,cmap='gray')
  plt.title("Original gray scale")
  plt.axis('off')
#sobel edge detection
  plt.subplot(2,2,2)
  plt.imshow(sobel,cmap='gray')
  plt.title("Sobel edge detection")
  plt.axis('off')
#prewitt edge dectection
  plt.subplot(2,2,3)
  plt.imshow(prewitt,cmap='gray')
  plt.title("Prewitt edge detection")
  plt.axis('off')
#canny edge dectection
  plt.subplot(2,2,4)
  plt.imshow(canny,cmap='gray')
  plt.title("Canny edge detection")
  plt.axis('off')
  plt.show()

  plt.tight_layout()
  plt.show()
#read image
img=cv2.imread('/content/image.1.jpeg')

if img is None:
  print("error.image not found")
else:
  pass

# %%
#read image
img=cv2.imread("/content/image.1.jpeg")

if img is None:
  print("error.image not found")
else:
  pass

# %%
def show_comparsion(original, sobel, prewitt, canny):
  plt.figure(figsize=(12,10))

  # Original image
  plt.subplot(2,2,1)
  plt.imshow(original, cmap='gray')
  plt.title("Original Grayscale Image")
  plt.axis('off')

  # Sobel Edge Detection
  plt.subplot(2,2,2)
  plt.imshow(sobel, cmap='gray')
  plt.title("Sobel Edge Detection")
  plt.axis('off')

  # Prewitt Edge Detection
  plt.subplot(2,2,3)
  plt.imshow(prewitt, cmap='gray')
  plt.title("Prewitt Edge Detection")
  plt.axis('off')

  # Canny Edge Detection
  plt.subplot(2,2,4)
  plt.imshow(canny, cmap='gray')
  plt.title("Canny Edge Detection")
  plt.axis('off')

  plt.tight_layout()
  plt.show()



# Load image
image_path = '/content/image.1.jpeg'
original_image = cv2.imread(image_path)

# Check if image loaded successfully
if original_image is None:
    print(f"Error: Could not load image from {image_path}")
else:
    # Convert to grayscale
    gray_image = cv2.cvtColor(original_image, cv2.COLOR_BGR2GRAY)

    # Apply Gaussian blur to reduce noise for better edge detection
    blurred_image = cv2.GaussianBlur(gray_image, (5, 5), 0)

    # Sobel Edge Detection
    sobel_x = cv2.Sobel(blurred_image, cv2.CV_64F, 1, 0, ksize=3)
    sobel_y = cv2.Sobel(blurred_image, cv2.CV_64F, 0, 1, ksize=3)
    sobel_magnitude = np.sqrt(sobel_x**2 + sobel_y**2)
    sobel = cv2.normalize(sobel_magnitude, None, 0, 255, cv2.NORM_MINMAX, cv2.CV_8U)

    # Prewitt Edge Detection
    kernel_prewitt_x = np.array([[-1, 0, 1], [-1, 0, 1], [-1, 0, 1]])
    kernel_prewitt_y = np.array([[-1, -1, -1], [0, 0, 0], [1, 1, 1]])

    prewitt_x = cv2.filter2D(blurred_image, -1, kernel_prewitt_x)
    prewitt_y = cv2.filter2D(blurred_image, -1, kernel_prewitt_y)
    prewitt_magnitude = np.sqrt(prewitt_x**2 + prewitt_y**2)
    prewitt = cv2.normalize(prewitt_magnitude, None, 0, 255, cv2.NORM_MINMAX, cv2.CV_8U)

    # Canny Edge Detection
    canny = cv2.Canny(blurred_image, 100, 200)

    # Display the results
    show_comparsion(gray_image, sobel, prewitt, canny)
